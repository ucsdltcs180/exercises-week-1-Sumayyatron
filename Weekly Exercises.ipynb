# %%
import pandas as pd

# %%
df = pd.read_csv("feeding-america.csv",index_col='date')

# %%
print(df['recipe_class'].unique())
# Out:
# ['soups' 'meatfishgame' 'fruitvegbeans' 'eggscheesedairy' 'breadsweets'
#  'beverages' 'accompaniments' 'medhealth']

# %%
print(df['recipe_class'].value_counts())
# Out:
# breadsweets        14630
# meatfishgame       11477
# fruitvegbeans       7085
# accompaniments      5495
# eggscheesedairy     4150
# soups               2631
# beverages           2031
# medhealth            533
# Name: recipe_class, dtype: int64

# %%
df['recipe_class'].value_counts().plot(kind='bar', color="C0", width=0.1)
# Out:
# <AxesSubplot: >

# %%
rg = df['region']

# %%
print(rg.unique())
# Out:
# ['ethnic' 'general' 'northeast' 'midwest' 'west' 'south']

# %%
df['region'].value_counts()
# Out:
# general      35508
# ethnic        7040
# midwest       2043
# northeast     1320
# south         1094
# west          1027
# Name: region, dtype: int64

# %%
df['region'].value_counts().plot(kind='bar', color="C0", width=0.05)
# Out:
# <AxesSubplot: >
